# %%
import requests
print(requests)
# Out:
# <module 'requests' from 'C:\\Users\\weaar\\anaconda3\\lib\\site-packages\\requests\\__init__.py'>

# %%
poke_res = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')

poke_res
# Out:
# <Response [200]>

# %%
poke_data = poke_res.json()
poke_data
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 25,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 25,
# ...

# %%
def get_pokemon_info(name):
    response = requests.get(f"https://pokeapi.co/api/v2/pokemon/{name}") 
    data = response.json()
    name = data["name"]
    height = data["height"]
    weight = data["weight"]
    pokemon_info = {"name": name, "height": height, "weight": weight}
    return pokemon_info
    input("What is your pokemon's name? ")

# %%
pokemon_info = get_pokemon_info("ditto")
print(pokemon_info)
#I cannot get an input to work...
# Out:
# {'name': 'ditto', 'height': 3, 'weight': 40}

# %%
# pokemon_info = get_pokemon_info("ditto")
# print(pokemon_info)
# pokemon_name = input("What is the name of your pokemon? ")
# pokemon_height = get_pokemon_info["height"]
# pokemon_weight = get_pokemon_info["weight"]
# print(f"{pokemon_name.title()} is {pokemon_height} feet tall and weighs {pokemon_weight} pounds.")
# Out:
# {'name': 'ditto', 'height': 3, 'weight': 40}
# What is the name of your pokemon? clefairy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26188\1837791993.py in <module>
#       2 print(pokemon_info)
#       3 pokemon_name = input("What is the name of your pokemon? ")
# ----> 4 pokemon_height = get_pokemon_info["height"]
#       5 pokemon_weight = get_pokemon_info["weight"]
#       6 print(f"{pokemon_name.title()} is {pokemon_height} feet tall and weighs {pokemon_weight} pounds.")
#
# TypeError: 'function' object is not subscriptable
